# %%
import pandas as pd

# %%
w_a_con = pd.read_csv('https://raw.githubusercontent.com/ustutz/Dataquest/master/Data_Analyst/Step_2_Intermediate_Python_and_Pandas/2_Data_Analysis_with_Pandas_Intermediate/2_Computation_with_NumPy/5_Replacing_values/world_alcohol.csv')
w_a_con
# Out:
#       Year       WHO region                   Country Beverage Types  \
# 0     1986  Western Pacific                  Viet Nam           Wine
# 1     1986         Americas                   Uruguay          Other
# 2     1985           Africa              Cte d'Ivoire           Wine
# 3     1986         Americas                  Colombia           Beer
# 4     1987         Americas     Saint Kitts and Nevis           Beer
# ...    ...              ...                       ...            ...
# 3252  1984           Africa  Central African Republic           Wine
# 3253  1986  Western Pacific                      Fiji        Spirits
# 3254  1986           Europe               Switzerland        Spirits
# 3255  1987  Western Pacific          Papua New Guinea          Other
# 3256  1986           Africa                 Swaziland          Other
#
#       Display Value
# 0              0.00
# 1              0.50
# 2              1.62
# 3              4.27
# 4              1.98
# ...             ...
# 3252           0.46
# 3253           0.05
# 3254           2.54
# 3255           0.00
# 3256           5.15
#
# [3257 rows x 5 columns]

# %%
print('\nShape of the dataframe: ',w_a_con.shape)
print('\nNumber of rows: ',w_a_con.shape[0])
print('\nNumber of column: ',w_a_con.shape[1])
# Out:
# Shape of the dataframe:  (3257, 5)
#
# Number of rows:  3257
#
# Number of column:  5

# %%
w_a_con.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
print("\nExtract Column Names:")
print(w_a_con.columns)
# Out:
# Extract Column Names:
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %% [markdown]
# #### Write a Pandas program to select first 2 rows, 2 columns and specific two columns from World alcohol consumption dataset.

# %%
print("\nSelect first 2 rows:")
w_a_con.iloc[:2]
# Out:
# Select first 2 rows:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0
# 1  1986         Americas   Uruguay          Other            0.5

# %%
w_a_con.head(2)
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0
# 1  1986         Americas   Uruguay          Other            0.5

# %%
print("\nSelect first 2 columns:")
w_a_con.iloc[:,:2].head()
# Out:
# Select first 2 columns:
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas
# 2  1985           Africa
# 3  1986         Americas
# 4  1987         Americas

# %%
print("\nSelect 2 specific columns:")
w_a_con[['Display Value', 'Year']].head()
# Out:
# Select 2 specific columns:
#    Display Value  Year
# 0           0.00  1986
# 1           0.50  1986
# 2           1.62  1985
# 3           4.27  1986
# 4           1.98  1987

# %% [markdown]
# #### Write a Pandas program to select random number of rows, fraction of random rows from World alcohol consumption dataset.

# %%
print("\nSelect random number of rows:")
w_a_con.sample(5)
# Out:
# Select random number of rows:
#       Year       WHO region                           Country Beverage Types  \
# 2641  1984           Africa                             Benin           Beer
# 64    1989         Americas  Bolivia (Plurinational State of)           Beer
# 249   1986         Americas                Dominican Republic           Beer
# 2529  1985  South-East Asia                             India           Wine
# 637   1985           Africa       United Republic of Tanzania           Wine
#
#       Display Value
# 2641           0.85
# 64             1.26
# 249            1.24
# 2529           0.00
# 637            0.00

# %%
print("\nSelect fraction of randome rows:")
w_a_con.sample(frac=0.02)
# Out:
# Select fraction of randome rows:
#       Year             WHO region     Country Beverage Types  Display Value
# 2842  1985  Eastern Mediterranean      Jordan          Other            NaN
# 353   1986                 Europe    Portugal           Beer           3.00
# 2753  1989               Americas      Belize          Other            NaN
# 2324  1987                 Europe  Kyrgyzstan        Spirits           1.59
# 1205  1989                 Europe    Bulgaria        Spirits           3.98
# ...    ...                    ...         ...            ...            ...
# 151   1989               Americas        Peru        Spirits           2.99
# 1493  1985                 Africa       Congo           Beer           2.67
# 1438  1987                 Africa        Togo        Spirits           0.28
# 301   1987  Eastern Mediterranean     Morocco          Other           0.00
# 2672  1986                 Africa      Guinea        Spirits           0.07
#
# [65 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to find and drop the missing values from World alcohol consumption dataset.

# %%
print("\nMissing values:")
w_a_con.isnull()
# Out:
# Missing values:
#        Year  WHO region  Country  Beverage Types  Display Value
# 0     False       False    False           False          False
# 1     False       False    False           False          False
# 2     False       False    False           False          False
# 3     False       False    False           False          False
# 4     False       False    False           False          False
# ...     ...         ...      ...             ...            ...
# 3252  False       False    False           False          False
# 3253  False       False    False           False          False
# 3254  False       False    False           False          False
# 3255  False       False    False           False          False
# 3256  False       False    False           False          False
#
# [3257 rows x 5 columns]

# %%
print("\nDropping the missing values:")
w_a_con.dropna()
# Out:
# Dropping the missing values:
#       Year       WHO region                   Country Beverage Types  \
# 0     1986  Western Pacific                  Viet Nam           Wine
# 1     1986         Americas                   Uruguay          Other
# 2     1985           Africa              Cte d'Ivoire           Wine
# 3     1986         Americas                  Colombia           Beer
# 4     1987         Americas     Saint Kitts and Nevis           Beer
# ...    ...              ...                       ...            ...
# 3252  1984           Africa  Central African Republic           Wine
# 3253  1986  Western Pacific                      Fiji        Spirits
# 3254  1986           Europe               Switzerland        Spirits
# 3255  1987  Western Pacific          Papua New Guinea          Other
# 3256  1986           Africa                 Swaziland          Other
#
#       Display Value
# 0              0.00
# 1              0.50
# 2              1.62
# 3              4.27
# 4              1.98
# ...             ...
# 3252           0.46
# 3253           0.05
# 3254           2.54
# 3255           0.00
# 3256           5.15
#
# [3035 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to remove the duplicates from 'WHO region' column of World alcohol consumption dataset.

# %%
w_a_con.drop_duplicates('WHO region')
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %% [markdown]
# #### Write a Pandas program to find out the alcohol consumption of a given year from the world alcohol consumption dataset.

# %%
print("\nThe world alcohol consumption details in the year 1985:")
w_a_con[w_a_con['Year']==1985].head(10)
# Out:
# The world alcohol consumption details in the year 1985:
#     Year       WHO region                                            Country  \
# 2   1985           Africa                                       Cte d'Ivoire
# 7   1985           Africa                                             Angola
# 12  1985  Western Pacific                   Lao People's Democratic Republic
# 14  1985  Western Pacific                                           Viet Nam
# 24  1985           Africa                                            Comoros
# 26  1985           Europe  United Kingdom of Great Britain and Northern I...
# 33  1985           Africa                                         Mauritania
# 35  1985         Americas                              Saint Kitts and Nevis
# 44  1985           Europe                                          Lithuania
# 50  1985           Europe                                        Switzerland
#
#    Beverage Types  Display Value
# 2            Wine           1.62
# 7         Spirits           0.39
# 12           Beer           0.00
# 14        Spirits           0.05
# 24          Other            NaN
# 26           Wine           1.36
# 33          Other           0.00
# 35        Spirits           2.24
# 44          Other            NaN
# 50          Other           0.30

# %%
print("\nThe world alcohol consumption details in the year 1989:")
w_a_con[w_a_con['Year']==1989]
# Out:
# The world alcohol consumption details in the year 1989:
#       Year             WHO region                           Country  \
# 11    1989               Americas                         Guatemala
# 17    1989                 Africa                        Seychelles
# 21    1989               Americas                        Costa Rica
# 32    1989                 Africa                         Mauritius
# 45    1989                 Africa                          Zimbabwe
# ...    ...                    ...                               ...
# 3227  1989               Americas  Bolivia (Plurinational State of)
# 3228  1989                 Africa                        Madagascar
# 3231  1989  Eastern Mediterranean                           Morocco
# 3246  1989                 Europe                            Poland
# 3249  1989                 Europe                            Turkey
#
#      Beverage Types  Display Value
# 11             Beer           0.62
# 17             Beer           2.23
# 21          Spirits           4.51
# 32             Beer           1.60
# 45             Beer           0.19
# ...             ...            ...
# 3227           Wine           0.08
# 3228           Wine           0.19
# 3231        Spirits           0.07
# 3246           Beer           2.03
# 3249          Other           0.00
#
# [655 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to find out the alcohol consumption details in the year '1987' or '1989' from the world alcohol consumption dataset.

# %%
print("\nThe world alcohol consumption details where year is 1987 or 1989:")
w_a_con[(w_a_con['Year']==1987) | (w_a_con['Year']==1989)].head(10)
# Out:
# The world alcohol consumption details where year is 1987 or 1989:
#     Year       WHO region                Country Beverage Types  Display Value
# 4   1987         Americas  Saint Kitts and Nevis           Beer           1.98
# 5   1987         Americas              Guatemala          Other           0.00
# 6   1987           Africa              Mauritius           Wine           0.13
# 10  1987           Africa               Botswana           Wine           0.20
# 11  1989         Americas              Guatemala           Beer           0.62
# 15  1987           Africa          Guinea-Bissau           Wine           0.07
# 17  1989           Africa             Seychelles           Beer           2.23
# 21  1989         Americas             Costa Rica        Spirits           4.51
# 28  1987  Western Pacific               Viet Nam           Beer           0.11
# 32  1989           Africa              Mauritius           Beer           1.60

# %% [markdown]
# #### Write a Pandas program to find out the alcohol consumption details by the 'Americas' in the year '1985' from the world alcohol consumption dataset

# %%
w_a_con[(w_a_con['Year']==1985) & (w_a_con['WHO region']=='Americas')]
# Out:
#       Year WHO region                Country Beverage Types  Display Value
# 35    1985   Americas  Saint Kitts and Nevis        Spirits           2.24
# 110   1985   Americas                 Brazil           Beer           1.42
# 119   1985   Americas                  Chile           Beer           1.17
# 258   1985   Americas                Bahamas           Wine           1.90
# 298   1985   Americas              Argentina          Other           0.00
# ...    ...        ...                    ...            ...            ...
# 3092  1985   Americas              Guatemala           Wine           0.01
# 3093  1985   Americas    Trinidad and Tobago        Spirits           2.84
# 3121  1985   Americas               Paraguay          Other           0.00
# 3146  1985   Americas            Saint Lucia           Wine           0.46
# 3159  1985   Americas                   Peru          Other           0.00
#
# [123 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to find out the alcohol consumption details in the year '1986' where WHO region is 'Western Pacific' and country is 'VietNam' from the world alcohol consumption dataset.

# %%
print("\nThe world alcohol consumption details in the year 1986 where WHO region is Western Pacific and country is VietNam :")
w_a_con[(w_a_con['Year']==1986) & (w_a_con['WHO region']=='Western Pacific') & (w_a_con['Country']=='Viet Nam')]
# Out:
# The world alcohol consumption details in the year 1986 where WHO region is Western Pacific and country is VietNam :
#       Year       WHO region   Country Beverage Types  Display Value
# 0     1986  Western Pacific  Viet Nam           Wine           0.00
# 898   1986  Western Pacific  Viet Nam          Other            NaN
# 2100  1986  Western Pacific  Viet Nam           Beer           0.12
# 3239  1986  Western Pacific  Viet Nam        Spirits           0.05

# %% [markdown]
# #### Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' from the world alcohol consumption dataset.

# %%
w_a_con[ w_a_con['WHO region']=='Americas'].query('Year == 1986 or Year==1989')
# Out:
#       Year WHO region                           Country Beverage Types  \
# 1     1986   Americas                           Uruguay          Other
# 3     1986   Americas                          Colombia           Beer
# 8     1986   Americas               Antigua and Barbuda        Spirits
# 11    1989   Americas                         Guatemala           Beer
# 21    1989   Americas                        Costa Rica        Spirits
# ...    ...        ...                               ...            ...
# 3211  1986   Americas                            Canada           Wine
# 3226  1986   Americas                          Paraguay           Wine
# 3227  1989   Americas  Bolivia (Plurinational State of)           Wine
# 3232  1986   Americas                          Paraguay        Spirits
# 3235  1986   Americas                            Belize           Beer
#
#       Display Value
# 1              0.50
# 3              4.27
# 8              1.55
# 11             0.62
# 21             4.51
# ...             ...
# 3211           1.33
# 3226           0.36
# 3227           0.08
# 3232           5.17
# 3235           1.35
#
# [248 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset.

# %%
print("\nThe world alcohol consumption details in the year ‘1986’ or ‘1989’ where  WHO region is ‘Americas’  or 'Europe':")
w_a_con[((w_a_con['Year']==1985) | (w_a_con['Year']==1989)) & ((w_a_con['WHO region']=='Americas') 
         | (w_a_con['WHO region']=='Europe'))].head(10)
# Out:
# The world alcohol consumption details in the year ‘1986’ or ‘1989’ where  WHO region is ‘Americas’  or 'Europe':
#     Year WHO region                                            Country  \
# 11  1989   Americas                                          Guatemala
# 21  1989   Americas                                         Costa Rica
# 26  1985     Europe  United Kingdom of Great Britain and Northern I...
# 35  1985   Americas                              Saint Kitts and Nevis
# 44  1985     Europe                                          Lithuania
# 50  1985     Europe                                        Switzerland
# 55  1989   Americas                                           Suriname
# 57  1989     Europe                                            Croatia
# 64  1989   Americas                   Bolivia (Plurinational State of)
# 78  1989   Americas                                            Jamaica
#
#    Beverage Types  Display Value
# 11           Beer           0.62
# 21        Spirits           4.51
# 26           Wine           1.36
# 35        Spirits           2.24
# 44          Other            NaN
# 50          Other           0.30
# 55           Wine           0.04
# 57           Wine           5.10
# 64           Beer           1.26
# 78          Other           0.00

# %% [markdown]
# #### Write a Pandas program to find out the records where consumption of beverages per person average >=5 and Beverage Types is Beer from world alcohol consumption dataset.

# %%
print("\nThe world alcohol consumption details: average consumption of \nbeverages per person >=5 and Beverage Types is Beer:")
w_a_con[(w_a_con['Display Value'] >= 5) & (w_a_con['Beverage Types'] == 'Beer')].head(10)
# Out:
# The world alcohol consumption details: average consumption of
# beverages per person >=5 and Beverage Types is Beer:
#      Year       WHO region                                            Country  \
# 41   1986           Europe                                     Czech Republic
# 115  1986           Europe                                            Belgium
# 133  1989           Europe                                            Belgium
# 143  1987           Europe                                            Ireland
# 154  1987           Europe                                            Belgium
# 241  1986           Europe  United Kingdom of Great Britain and Northern I...
# 247  1989           Africa                                              Gabon
# 293  1985           Africa                                              Gabon
# 325  1985  Western Pacific                                          Australia
# 352  1984         Americas                                             Canada
#
#     Beverage Types  Display Value
# 41            Beer           6.82
# 115           Beer           7.36
# 133           Beer           7.01
# 143           Beer           7.49
# 154           Beer           7.42
# 241           Beer           6.73
# 247           Beer           6.49
# 293           Beer           8.33
# 325           Beer           7.73
# 352           Beer           5.00

# %% [markdown]
# #### Write a Pandas program to find out the records where consumption of beverages per person average >=4 and Beverage Types is Beer, Wine, Spirits from world alcohol consumption dataset.

# %%
w_a_con[(w_a_con['Display Value'] >= 4) & (w_a_con['Beverage Types'].isin(['Beer','Wine','Spirits']))]
# Out:
#       Year WHO region                                            Country  \
# 3     1986   Americas                                           Colombia
# 21    1989   Americas                                         Costa Rica
# 41    1986     Europe                                     Czech Republic
# 57    1989     Europe                                            Croatia
# 91    1989     Europe                                           Bulgaria
# ...    ...        ...                                                ...
# 3214  1987     Europe  United Kingdom of Great Britain and Northern I...
# 3220  1986     Africa                                           Zimbabwe
# 3232  1986   Americas                                           Paraguay
# 3247  1984     Europe                                             Latvia
# 3248  1986     Europe                                           Bulgaria
#
#      Beverage Types  Display Value
# 3              Beer           4.27
# 21          Spirits           4.51
# 41             Beer           6.82
# 57             Wine           5.10
# 91             Beer           4.43
# ...             ...            ...
# 3214           Beer           5.49
# 3220        Spirits           5.57
# 3232        Spirits           5.17
# 3247        Spirits           7.50
# 3248        Spirits           4.32
#
# [249 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to filter the specified columns and records by range from world alcohol consumption dataset.

# %%
print("\nFiltering records by label or index:")
w_a_con.loc[0:4, ["WHO region", "Beverage Types"]]
# Out:
# Filtering records by label or index:
#         WHO region Beverage Types
# 0  Western Pacific           Wine
# 1         Americas          Other
# 2           Africa           Wine
# 3         Americas           Beer
# 4         Americas           Beer

# %% [markdown]
# #### Write a Pandas program to filter those records where WHO region contains "Ea" substring from world alcohol consumption dataset.

# %%
# Remove NA / NaN values
new_w_a_con = w_a_con.dropna()
print("\nMatch if  a given column has a particular sub string:")
new_w_a_con[new_w_a_con["WHO region"].str.contains("Ea")]
# Out:
# Match if  a given column has a particular sub string:
#       Year             WHO region                                Country  \
# 13    1984  Eastern Mediterranean                            Afghanistan
# 20    1986        South-East Asia                                Myanmar
# 25    1984  Eastern Mediterranean                                Tunisia
# 27    1984  Eastern Mediterranean                                Bahrain
# 36    1987  Eastern Mediterranean                                  Egypt
# ...    ...                    ...                                    ...
# 3223  1984        South-East Asia  Democratic People's Republic of Korea
# 3231  1989  Eastern Mediterranean                                Morocco
# 3241  1984  Eastern Mediterranean                               Djibouti
# 3244  1986  Eastern Mediterranean                   United Arab Emirates
# 3245  1985        South-East Asia                                  India
#
#      Beverage Types  Display Value
# 13            Other           0.00
# 20             Wine           0.00
# 25            Other           0.00
# 27             Beer           2.22
# 36             Beer           0.07
# ...             ...            ...
# 3223           Beer           0.37
# 3231        Spirits           0.07
# 3241           Wine           0.51
# 3244          Other           0.00
# 3245        Spirits           1.24
#
# [565 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to filter those records where WHO region matches with multiple values (Africa, Eastern Mediterranean, Europe) from world alcohol consumption dataset.

# %%
print("\nFilter by matching multiple values in a given dataframe:")
w_a_con.loc[w_a_con["WHO region"].isin(["Africa", "Eastern Mediterranean", "Europe"])]
# Out:
# Filter by matching multiple values in a given dataframe:
#       Year WHO region                   Country Beverage Types  Display Value
# 2     1985     Africa              Cte d'Ivoire           Wine           1.62
# 6     1987     Africa                 Mauritius           Wine           0.13
# 7     1985     Africa                    Angola        Spirits           0.39
# 9     1984     Africa                   Nigeria          Other           6.10
# 10    1987     Africa                  Botswana           Wine           0.20
# ...    ...        ...                       ...            ...            ...
# 3250  1987     Europe                   Iceland          Other           0.01
# 3251  1984     Africa                    Angola           Wine           0.57
# 3252  1984     Africa  Central African Republic           Wine           0.46
# 3254  1986     Europe               Switzerland        Spirits           2.54
# 3256  1986     Africa                 Swaziland          Other           5.15
#
# [2059 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to filter all records where the average consumption of beverages per person from .5 to 2.50 in world alcohol consumption dataset.

# %%
print("\nFilter all records where the average consumption of beverages per person from .5 to 2.50.:")
w_a_con[(w_a_con['Display Value'] < 2.5) & (w_a_con['Display Value']>.5)].head()
# Out:
# Filter all records where the average consumption of beverages per person from .5 to 2.50.:
#     Year WHO region                Country Beverage Types  Display Value
# 2   1985     Africa           Cte d'Ivoire           Wine           1.62
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 8   1986   Americas    Antigua and Barbuda        Spirits           1.55
# 11  1989   Americas              Guatemala           Beer           0.62
# 17  1989     Africa             Seychelles           Beer           2.23

# %% [markdown]
# #### Write a Pandas program to find average consumption of wine per person greater than 2 in world alcohol consumption dataset.

# %%
print("\nAverage consumption of wine per person greater than 2:")
w_a_con[(w_a_con['Beverage Types'] == 'Wine') & (w_a_con['Display Value'] > .2)].count()
# Out:
# Average consumption of wine per person greater than 2:
# Year              326
# WHO region        326
# Country           326
# Beverage Types    326
# Display Value     326
# dtype: int64

# %%
w_a_con[(w_a_con['Beverage Types'] == 'Wine') & (w_a_con['Display Value'] > .2)]
# Out:
#       Year             WHO region  \
# 2     1985                 Africa
# 26    1985                 Europe
# 34    1986                 Europe
# 49    1986                 Europe
# 57    1989                 Europe
# ...    ...                    ...
# 3226  1986               Americas
# 3241  1984  Eastern Mediterranean
# 3243  1985                 Europe
# 3251  1984                 Africa
# 3252  1984                 Africa
#
#                                                 Country Beverage Types  \
# 2                                          Cte d'Ivoire           Wine
# 26    United Kingdom of Great Britain and Northern I...           Wine
# 34                                   Russian Federation           Wine
# 49                                                Malta           Wine
# 57                                              Croatia           Wine
# ...                                                 ...            ...
# 3226                                           Paraguay           Wine
# 3241                                           Djibouti           Wine
# 3243                                           Slovakia           Wine
# 3251                                             Angola           Wine
# 3252                           Central African Republic           Wine
#
#       Display Value
# 2              1.62
# 26             1.36
# 34             0.80
# 49             1.49
# 57             5.10
# ...             ...
# 3226           0.36
# 3241           0.51
# 3243           2.60
# 3251           0.57
# 3252           0.46
#
# [326 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to filter rows based on row numbers ended with 0, like 0, 10, 20, 30 from world alcohol consumption dataset.

# %%
print("\nFilter rows based on row numbers ended with 0, like 0, 10, 20, 30:")
w_a_con.filter(regex='0$', axis=0)
# Out:
# Filter rows based on row numbers ended with 0, like 0, 10, 20, 30:
#       Year             WHO region       Country Beverage Types  Display Value
# 0     1986        Western Pacific      Viet Nam           Wine           0.00
# 10    1987                 Africa      Botswana           Wine           0.20
# 20    1986        South-East Asia       Myanmar           Wine           0.00
# 30    1986                 Africa  Sierra Leone          Other           4.48
# 40    1987                 Europe       Austria        Spirits           1.90
# ...    ...                    ...           ...            ...            ...
# 3210  1986  Eastern Mediterranean      Djibouti          Other           0.00
# 3220  1986                 Africa      Zimbabwe        Spirits           5.57
# 3230  1987                 Europe        France        Spirits           2.77
# 3240  1986                 Europe      Slovenia           Beer           3.71
# 3250  1987                 Europe       Iceland          Other           0.01
#
# [326 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to select consecutive columns and also select rows with Index label 0 to 9 with some columns from world alcohol consumption dataset.

# %%
print("\nSelect consecutive columns:")
w_a_con.loc[:,"Country":"Display Value"].head()
# Out:
# Select consecutive columns:
#                  Country Beverage Types  Display Value
# 0               Viet Nam           Wine           0.00
# 1                Uruguay          Other           0.50
# 2           Cte d'Ivoire           Wine           1.62
# 3               Colombia           Beer           4.27
# 4  Saint Kitts and Nevis           Beer           1.98

# %%
print("\nAlternate command:")
w_a_con.iloc[:,2:5].head()
# Out:
# Alternate command:
#                  Country Beverage Types  Display Value
# 0               Viet Nam           Wine           0.00
# 1                Uruguay          Other           0.50
# 2           Cte d'Ivoire           Wine           1.62
# 3               Colombia           Beer           4.27
# 4  Saint Kitts and Nevis           Beer           1.98

# %%
print("\nSelect rows with Index label 0 to 9 with specific columns:")
w_a_con.loc[0:9,["Year","Country","Display Value"]]
# Out:
# Select rows with Index label 0 to 9 with specific columns:
#    Year                Country  Display Value
# 0  1986               Viet Nam           0.00
# 1  1986                Uruguay           0.50
# 2  1985           Cte d'Ivoire           1.62
# 3  1986               Colombia           4.27
# 4  1987  Saint Kitts and Nevis           1.98
# 5  1987              Guatemala           0.00
# 6  1987              Mauritius           0.13
# 7  1985                 Angola           0.39
# 8  1986    Antigua and Barbuda           1.55
# 9  1984                Nigeria           6.10

# %% [markdown]
# #### Write a Pandas program to rename all and only some of the column names from world alcohol consumption dataset.

# %%
w_a_con.columns = ['year','who_region','country','beverage_types','display_values']

# %%
w_a_con.head()
# Out:
#    year       who_region                country beverage_types  display_values
# 0  1986  Western Pacific               Viet Nam           Wine            0.00
# 1  1986         Americas                Uruguay          Other            0.50
# 2  1985           Africa           Cte d'Ivoire           Wine            1.62
# 3  1986         Americas               Colombia           Beer            4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer            1.98

# %%
print("\nRenaming only some of the column names:")
new_w_a_con.rename(columns = {"WHO region":"WHO_region","Display Value":"Display_Value" },inplace = True)
w_a_con.head()
# Out:
# Renaming only some of the column names:
# E:\Anaconda\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    year       who_region                country beverage_types  display_values
# 0  1986  Western Pacific               Viet Nam           Wine            0.00
# 1  1986         Americas                Uruguay          Other            0.50
# 2  1985           Africa           Cte d'Ivoire           Wine            1.62
# 3  1986         Americas               Colombia           Beer            4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer            1.98

# %% [markdown]
# #### Write a Pandas program to find which years have all non-zero values and which years have any non-zero values from world alcohol consumption dataset.

# %%
print("\nFind which years have all non-zero values:")
w_a_con.loc[:,w_a_con.all()]
# Out:
# Find which years have all non-zero values:
#       year       who_region                   country beverage_types
# 0     1986  Western Pacific                  Viet Nam           Wine
# 1     1986         Americas                   Uruguay          Other
# 2     1985           Africa              Cte d'Ivoire           Wine
# 3     1986         Americas                  Colombia           Beer
# 4     1987         Americas     Saint Kitts and Nevis           Beer
# ...    ...              ...                       ...            ...
# 3252  1984           Africa  Central African Republic           Wine
# 3253  1986  Western Pacific                      Fiji        Spirits
# 3254  1986           Europe               Switzerland        Spirits
# 3255  1987  Western Pacific          Papua New Guinea          Other
# 3256  1986           Africa                 Swaziland          Other
#
# [3257 rows x 4 columns]

# %%
print("\nFind which years have any non-zero values:")
w_a_con.loc[:,w_a_con.any()]
# Out:
# Find which years have any non-zero values:
#       year       who_region                   country beverage_types  \
# 0     1986  Western Pacific                  Viet Nam           Wine
# 1     1986         Americas                   Uruguay          Other
# 2     1985           Africa              Cte d'Ivoire           Wine
# 3     1986         Americas                  Colombia           Beer
# 4     1987         Americas     Saint Kitts and Nevis           Beer
# ...    ...              ...                       ...            ...
# 3252  1984           Africa  Central African Republic           Wine
# 3253  1986  Western Pacific                      Fiji        Spirits
# 3254  1986           Europe               Switzerland        Spirits
# 3255  1987  Western Pacific          Papua New Guinea          Other
# 3256  1986           Africa                 Swaziland          Other
#
#       display_values
# 0               0.00
# 1               0.50
# 2               1.62
# 3               4.27
# 4               1.98
# ...              ...
# 3252            0.46
# 3253            0.05
# 3254            2.54
# 3255            0.00
# 3256            5.15
#
# [3257 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to filter all columns where all entries present, check which rows and columns has a NaN and finally drop rows with any NaNs from world alcohol consumption dataset.

# %%
print("\nFind  all columns which all entries present:")
w_a_con.loc[:, w_a_con.notnull().all()]
# Out:
# Find  all columns which all entries present:
#       year       who_region                   country beverage_types
# 0     1986  Western Pacific                  Viet Nam           Wine
# 1     1986         Americas                   Uruguay          Other
# 2     1985           Africa              Cte d'Ivoire           Wine
# 3     1986         Americas                  Colombia           Beer
# 4     1987         Americas     Saint Kitts and Nevis           Beer
# ...    ...              ...                       ...            ...
# 3252  1984           Africa  Central African Republic           Wine
# 3253  1986  Western Pacific                      Fiji        Spirits
# 3254  1986           Europe               Switzerland        Spirits
# 3255  1987  Western Pacific          Papua New Guinea          Other
# 3256  1986           Africa                 Swaziland          Other
#
# [3257 rows x 4 columns]

# %%
print("\nRows and columns has a NaN:")
w_a_con.loc[:,w_a_con.isnull().any()]
# Out:
# Rows and columns has a NaN:
#       display_values
# 0               0.00
# 1               0.50
# 2               1.62
# 3               4.27
# 4               1.98
# ...              ...
# 3252            0.46
# 3253            0.05
# 3254            2.54
# 3255            0.00
# 3256            5.15
#
# [3257 rows x 1 columns]

# %%
print("\nDrop rows with any NaNs:")
w_a_con.dropna(how='any')
# Out:
# Drop rows with any NaNs:
#       year       who_region                   country beverage_types  \
# 0     1986  Western Pacific                  Viet Nam           Wine
# 1     1986         Americas                   Uruguay          Other
# 2     1985           Africa              Cte d'Ivoire           Wine
# 3     1986         Americas                  Colombia           Beer
# 4     1987         Americas     Saint Kitts and Nevis           Beer
# ...    ...              ...                       ...            ...
# 3252  1984           Africa  Central African Republic           Wine
# 3253  1986  Western Pacific                      Fiji        Spirits
# 3254  1986           Europe               Switzerland        Spirits
# 3255  1987  Western Pacific          Papua New Guinea          Other
# 3256  1986           Africa                 Swaziland          Other
#
#       display_values
# 0               0.00
# 1               0.50
# 2               1.62
# 3               4.27
# 4               1.98
# ...              ...
# 3252            0.46
# 3253            0.05
# 3254            2.54
# 3255            0.00
# 3256            5.15
#
# [3035 rows x 5 columns]

# %% [markdown]
# #### Write a Pandas program to filter all records starting from the 'Year' column, access every other column from world alcohol consumption dataset.

# %%
w_a_con = pd.read_csv('https://raw.githubusercontent.com/ustutz/Dataquest/master/Data_Analyst/Step_2_Intermediate_Python_and_Pandas/2_Data_Analysis_with_Pandas_Intermediate/2_Computation_with_NumPy/5_Replacing_values/world_alcohol.csv')
print("\nFrom the 'Year' column, access every other column:")
w_a_con.loc[:,'Year'::2].head(10)
# Out:
# From the 'Year' column, access every other column:
#    Year                Country  Display Value
# 0  1986               Viet Nam           0.00
# 1  1986                Uruguay           0.50
# 2  1985           Cte d'Ivoire           1.62
# 3  1986               Colombia           4.27
# 4  1987  Saint Kitts and Nevis           1.98
# 5  1987              Guatemala           0.00
# 6  1987              Mauritius           0.13
# 7  1985                 Angola           0.39
# 8  1986    Antigua and Barbuda           1.55
# 9  1984                Nigeria           6.10

# %% [markdown]
# #### Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from world alcohol consumption dataset.

# %%
print("\nStarting from the 2nd row, access every 5th row:")
w_a_con.iloc[1::5].head(10)
# Out:
# Starting from the 2nd row, access every 5th row:
#     Year             WHO region  \
# 1   1986               Americas
# 6   1987                 Africa
# 11  1989               Americas
# 16  1984               Americas
# 21  1989               Americas
# 26  1985                 Europe
# 31  1986        Western Pacific
# 36  1987  Eastern Mediterranean
# 41  1986                 Europe
# 46  1987               Americas
#
#                                               Country Beverage Types  \
# 1                                             Uruguay          Other
# 6                                           Mauritius           Wine
# 11                                          Guatemala           Beer
# 16                                         Costa Rica           Wine
# 21                                         Costa Rica        Spirits
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 31                   Micronesia (Federated States of)           Wine
# 36                                              Egypt           Beer
# 41                                     Czech Republic           Beer
# 46                                Trinidad and Tobago        Spirits
#
#     Display Value
# 1            0.50
# 6            0.13
# 11           0.62
# 16           0.06
# 21           4.51
# 26           1.36
# 31           0.00
# 36           0.07
# 41           6.82
# 46           2.26
